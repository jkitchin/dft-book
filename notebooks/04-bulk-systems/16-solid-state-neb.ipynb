# %% [markdown]
# ### solid state NEB

# %% [markdown]
# cite:Caspersen10052005 Carter paper
# cite:sheppard:074103 recent Henkelman paper
#
# [http://scitation.aip.org/content/aip/journal/jcp/137/10/10.1063/1.4752249](http://scitation.aip.org/content/aip/journal/jcp/137/10/10.1063/1.4752249)
