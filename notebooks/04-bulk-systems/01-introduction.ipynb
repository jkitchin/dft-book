# %% [markdown]
# **Author:** root

# %% [markdown]
# ## Bulk systems
#
# See [http://arxiv.org/pdf/1204.2733.pdf](http://arxiv.org/pdf/1204.2733.pdf) for a very informative comparison of DFT codes for computing different bulk properties.
